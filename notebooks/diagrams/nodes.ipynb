# %% [markdown]
# + Programming

# %%
from diagrams import Diagram
from diagrams.programming.language import Python, R
from diagrams.programming.flowchart import Database

# %%
with Diagram("./imgs/python", filename='', show=False) as py:
    Python("python")
py

# %%
with Diagram("./imgs/r", show=False) as r:
    R("r")
r

# %%
with Diagram("./imgs/db", show=False) as db:
    Database("database")
db
